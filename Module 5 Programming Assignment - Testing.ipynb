# %% [markdown]
# ### __init__.py

# %%
# This is the function we are going to test
def sum(arg):
    total = 0
    for val in arg:
        total += val
    return total

# %% [markdown]
# ### test.py

# %%
# This is our test code, running in VS code
import unittest

from my_sum import sum
from fractions import Fraction


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

    def test_list_fraction(self):
        """
        Test that it can sum a list of fractions
        """
        data = [Fraction(1, 4), Fraction(1, 4), Fraction(2, 5)]
        result = sum(data)
        self.assertEqual(result, 1)

if __name__ == "__main_":
    unittest.main()

# %% [markdown]
# ### Run the test in the VS Code terminal

# %%
python -m unittest test

# %% [markdown]
# ### Test results output

# %%
F.
======================================================================
FAIL: test_list_fraction (test.TestSum.test_list_fraction)
Test that it can sum a list of fractions
----------------------------------------------------------------------
Traceback (most recent call last):
  File "F:\ITC\testing\test.py", line 22, in test_list_fraction
    self.assertEqual(result, 1)
AssertionError: Fraction(9, 10) != 1

----------------------------------------------------------------------
Ran 2 tests in 0.001s

FAILED (failures=1)

# %% [markdown]
# ### Analysis of Test Results
# #### "F." indicates that two tests were conducted. When running the test, unittest executes tests in the default order based on the alphabetical sequence of method names. Therefore, the test execution order is:
# #### test_list_fraction (failure, output 'F')
# #### test_list_int (Passed, output'.')
# #### The test_list_fraction test failed because the sum of the three fractions is '9/10', not '1' as I asserted. The failed test will display the complete traceback, precisely indicating line '22' of code caused the problem. The system threw an AssertionError and showed the comparison of the expected value and the actual value. This indicates that the test code correctly detected the error.
